# %%
# %sql
select month(start),count(*) ,sum(has_payer_coverage) as covered_by_payer , (sum(has_payer_coverage)
/count(*))*100 as covered_percentage from medical_pipeline.gold.fact_encounters group by month(start) order by month(start)
