# %%
# %sql
CREATE SCHEMA IF NOT EXISTS medical_project.gold;

# %%
% sql
create or replace  table medical_pipeline.gold.dim_patients as
with table1 as(
select id as patient_id,
concat(first_name , last_name) as name
gender,
race,
ethinicity from medical_pipeline.silver.patients) select * from tabel1
