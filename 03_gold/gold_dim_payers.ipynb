# %%
# %sql
CREATE SCHEMA IF NOT EXISTS medical_project.gold;

# %%
# %sql
create or replace table medical_pipeline.gold.dim_payers as
select id as payer_id, name as payer_name from medical_pipeline.silver.payers ;
